# %%
from freealg.distributions import MarchenkoPastur
mp = MarchenkoPastur(1/50)

latex = True
ext = '.png'

# %%
rho = mp.density(plot=True, latex=latex, save='mp_density' + ext)
# Out:
# Plot saved to "/home/sia/work/github/freealg/notebooks/mp_density.png".

# %%
s = mp.sample(1000, plot=True, latex=latex, save='mp_samples' + ext)
# Out:
# Plot saved to "/home/sia/work/github/freealg/notebooks/mp_samples.png".

# %%
hilb = mp.hilbert(plot=True, latex=latex, save='mp_hilbert' + ext)
# Out:
# Plot saved to "/home/sia/work/github/freealg/notebooks/mp_hilbert.png".

# %%
m1, m2 = mp.stieltjes(plot=True, latex=latex, save='mp_stieltjes' + ext)
# Out:
# Plot saved to "/home/sia/work/github/freealg/notebooks/mp_stieltjes.png".

# %%
m1_D, m2_D = mp.stieltjes(plot=True, on_disk=True, latex=latex, save='mp_stieltjes_disk' + ext)
# Out:
# Plot saved to "/home/sia/work/github/freealg/notebooks/mp_stieltjes_disk.png".
